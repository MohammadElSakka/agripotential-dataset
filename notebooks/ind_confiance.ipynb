# %%
import os
import sys 
sys.path.append(os.path.abspath(".."))
import numpy as np
import matplotlib.pyplot as plt

from scripts.dataset import Dataset

# %%
dataset = Dataset(download=False, root="..", ind_conf=3, iddiz=2.5 , icucs=3)
binary_mask = dataset.get_binary_mask()

# %%
dataset_size = np.sum(binary_mask) 
print(dataset_size)
# Out:
# 8992554

# %%
plt.imshow(binary_mask)
plt.show()

# %%
categorical_mask = dataset.get_categorical_potential_data("pot_global")

# %%
categorical_mask.shape
# Out:
# (10980, 10980, 5)

# %%
tmp = 0
for i in range(5):
    class_size = np.sum(categorical_mask[...,i])
    print(f"{int(class_size/dataset_size*100)}%")
    tmp += class_size
print(f"Sanity test: total = {int(tmp/dataset_size*100)}%")
# Out:
# 26%
# 22%
# 15%
# 18%
# 15%
# Sanity test: total = 100%
